# %%
import pandas as pd

# %%
sal=pd.read_csv("D:/Salaries.csv")

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %%
sal1=sal[sal['EmployeeName']=='JOSEPH DRISCOLL']

# %%
sal1
# Out:
#     Id     EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 24  25  JOSEPH DRISCOLL  CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
#
#     OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 24  31909.28       NaN  270324.91         270324.91  2011    NaN
#
#            Agency  Status
# 24  San Francisco     NaN

# %%
sal1['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
sal1['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653     True
# Name: TotalPayBenefits, Length: 148654, dtype: bool

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].max()]
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
sal[sal['TotalPayBenefits']==sal['TotalPayBenefits'].min()]
# Out:
#             Id EmployeeName                    JobTitle  BasePay  OvertimePay  \
# 148653  148654    Joe Lopez  Counselor, Log Cabin Ranch      0.0          0.0
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148653   -618.13       0.0   -618.13           -618.13  2014    NaN
#
#                Agency  Status
# 148653  San Francisco     NaN

# %%
ysal=sal.groupby('Year').mean()

# %%
ysal['TotalPayBenefits']
# Out:
# Year
# 2011     71744.103871
# 2012    100553.229232
# 2013    101440.519714
# 2014    100250.918884
# Name: TotalPayBenefits, dtype: float64

# %%
sal['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %%
df=sal['JobTitle'].value_counts(sort=True)

# %%
type(df)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
df2=sal[sal['Year']==2013]

# %%
df2
# Out:
#             Id          EmployeeName                        JobTitle  \
# 72925    72926        Gregory P Suhr                 Chief of Police
# 72926    72927  Joanne M Hayes-White          Chief, Fire Department
# 72927    72928           Samson  Lai  Battalion Chief, Fire Suppress
# 72928    72929       Ellen G Moffatt               Asst Med Examiner
# 72929    72930         Robert L Shaw    Dep Dir for Investments, Ret
# ...        ...                   ...                             ...
# 110526  110527        Arthur L Curry         PS Aide Health Services
# 110527  110528         Nereida  Vega                    Senior Clerk
# 110528  110529      Timothy E Gibson                Police Officer 3
# 110529  110530        Mark E Laherty                Police Officer 3
# 110530  110531         David P Kucia                Police Officer 3
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 72925   319275.01         0.00  20007.06  86533.21  339282.07
# ...

# %%
gf=df2.groupby(by='JobTitle')

# %%
gf.describe()
# Out:
#                                   Id                                        \
#                                count           mean           std      min
# JobTitle
# ASR Senior Office Specialist    21.0   93296.333333   3654.788329  88154.0
# ASR-Office Assistant            15.0  100377.000000   3043.996574  97029.0
# Account Clerk                   90.0   99437.044444   3476.674066  94739.0
# Accountant I                     3.0   93574.666667   1866.736814  92397.0
# Accountant II                   77.0   92664.870130   3328.498323  88566.0
# ...                              ...            ...           ...      ...
# Wire Rope Cable Maint Sprv       1.0   74250.000000           NaN  74250.0
# Worker's Comp Supervisor 1       3.0   90312.000000  12222.642636  82191.0
# Worker's Compensation Adjuster  25.0   90398.120000   5005.205560  86839.0
# X-Ray Laboratory Aide           34.0   98100.764706   5976.153968  89205.0
# ...

# %%
df5=df2['JobTitle'].value_counts(ascending=True)

# %%
df5
# Out:
# Chief, Fire Department              1
# Training Coordinator                1
# Crane Mechanic Supervisor           1
# Conservatorship/Case Mgt Sprv       1
# Graphics Supervisor                 1
#                                  ...
# Custodian                         789
# Public Svc Aide-Public Works      859
# Registered Nurse                 1231
# Special Nurse                    1445
# Transit Operator                 2295
# Name: JobTitle, Length: 1051, dtype: int64

# %%
i=0
count=0
while df5[i]==1:
    count+=1
    i+=1
print(count)
# Out:
# 202

# %%
dw=sal['JobTitle'].str.lower()

# %%
cg=dw.to_frame()

# %%
cg
# Out:
#                                               JobTitle
# 0       general manager-metropolitan transit authority
# 1                      captain iii (police department)
# 2                      captain iii (police department)
# 3                 wire rope cable maintenance mechanic
# 4         deputy chief of department,(fire department)
# ...                                                ...
# 148649                                       custodian
# 148650                                    not provided
# 148651                                    not provided
# 148652                                    not provided
# 148653                      counselor, log cabin ranch
#
# [148654 rows x 1 columns]

# %%
cg[cg['JobTitle'].str.contains('chief')]
# Out:
#                                             JobTitle
# 4       deputy chief of department,(fire department)
# 5                          assistant deputy chief ii
# 6                 battalion chief, (fire department)
# 8                 battalion chief, (fire department)
# 9             chief of department, (fire department)
# ...                                              ...
# 138011                chief deputy adlt probation of
# 139620                                   chief clerk
# 139709                      chief nursery specialist
# 140080                              chief preparator
# 140156                     chief stationary engineer
#
# [627 rows x 1 columns]

# %%
sal[sal['JobTitle'].str.contains('Chief')]
# Out:
#             Id         EmployeeName                        JobTitle  \
# 36160    36161         Gregory Suhr                 Chief of Police
# 36162    36163   Joanne Hayes-White          Chief, Fire Department
# 36169    36170         Brendan Ward  Battlion Chief, Fire Suppressi
# 36170    36171           Samson Lai  Battlion Chief, Fire Suppressi
# 36171    36172     Rudy Castellanos  Battlion Chief, Fire Suppressi
# ...        ...                  ...                             ...
# 138011  138012     Sharon C Jackson  Chief Deputy Adlt Probation Of
# 139620  139621          Anita S Lee                     Chief Clerk
# 139709  139710     George D Vaughan        Chief Nursery Specialist
# 140080  140081  Patrick W Gillespie                Chief Preparator
# 140156  140157  Christopher L Ochoa       Chief Stationary Engineer
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 36160   302578.00         0.00  18974.11  69810.19  321552.11
# ...

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
sal['Length']=sal['JobTitle'].str.len()

# %%
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
gh=sal[['TotalPayBenefits','Length']]

# %%
gh
# Out:
#         TotalPayBenefits  Length
# 0              567595.43      46
# 1              538909.28      31
# 2              335279.91      31
# 3              332343.61      36
# 4              326373.19      44
# ...                  ...     ...
# 148649              0.00       9
# 148650              0.00      12
# 148651              0.00      12
# 148652              0.00      12
# 148653           -618.13      26
#
# [148654 rows x 2 columns]

# %%
gh.corr()
# Out:
#                   TotalPayBenefits    Length
# TotalPayBenefits          1.000000 -0.036878
# Length                   -0.036878  1.000000
